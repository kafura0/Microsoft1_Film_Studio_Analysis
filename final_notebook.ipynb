# %% [markdown]
# # FILM INDUSTRY ANALYSIS

# %% [markdown]
# ![film_gif](https://media.giphy.com/media/26DOMQa5Ib2SmaRZm/giphy.gif)

# %% [markdown]
# * Author: Joan Kabura Njoroge
# * Course: Data Science Full Time
# * Scheduled project review date/time: May 28, 2021
# * Instructor name: Mark Tiba

# %% [markdown]
# # 1.BUSINESS UNDERSTANDING
# ## 1.1. Business problem:
# Microsoft wants to get in on the fun of huge firms producing original video content. Although they don't have any experience making movies, they have chosen to start a new film production company.My task is to research the categories of movies that are currently performing the best at the box office. I'll then turn those discoveries into useful information that the CEO of Microsoft's new film company may use to select what kinds of movies to make.
#
# ## 1.2. Success Indicator:
# 1. Does the length of the movie determine if the movie with have a high average rating?
# 2. Top 5 genres with highest return on investment?
# 3. Top 5 genres with the highest average rating?
# 4. Does a movie's running time have an impact on how well it does financially and how    popular it is?
# 5. What categories are most popular right now?
#
# # 2.DATA EXPLORATION
# ## 2.1. Importing the relevant packages

# %%
#import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandasql import sqldf

# %matplotlib inline

sns.set_style("dark")

pysqldf = lambda q: sqldf(q, globals())

# %% [markdown]
# # 2.2. Reading the datasets
#
# Relationship Diagram OF IM.db
#
# ![IM.db database schema](/movie_data_erd.jpeg)

# %%
import sqlite3
conn = sqlite3.connect('Data/im.db')

imdb_df = pd.read_sql("""SELECT name FROM sqlite_master WHERE type = 'table';""", conn)
imdb_df
# Out:
#             name
# 0   movie_basics
# 1      directors
# 2      known_for
# 3     movie_akas
# 4  movie_ratings
# 5        persons
# 6     principals
# 7        writers

# %%
movie_gross_df = pd.read_csv('Data/bom.movie_gross.csv')
movie_gross_df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...            ...   ...
# 3382           NaN  2018
# 3383           NaN  2018
# 3384           NaN  2018
# 3385           NaN  2018
# 3386           NaN  2018
#
# [3387 rows x 5 columns]

# %%
movie_info_df = pd.read_table('Data/movie_info.tsv', index_col=0)
movie_info_df.head(3)
# Out:
#                                              synopsis rating  \
# id
# 1   This gritty, fast-paced, and innovative police...      R
# 3   New York City, not-too-distant-future: Eric Pa...      R
# 5   Illeana Douglas delivers a superb performance ...      R
#
#                                   genre          director  \
# id
# 1   Action and Adventure|Classics|Drama  William Friedkin
# 3     Drama|Science Fiction and Fantasy  David Cronenberg
# 5     Drama|Musical and Performing Arts    Allison Anders
#
#                           writer  theater_date      dvd_date currency  \
# id
# 1                 Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 3   David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 5                 Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
#
#    box_office      runtime             studio
# id
# 1         NaN  104 minutes                NaN
# 3     600,000  108 minutes  Entertainment One
# 5         NaN  116 minutes                NaN

# %%
reviews_df = pd.read_table('Data/reviews.tsv', index_col=0, encoding='windows-1252')

reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54432 entries, 3 to 2000
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   review      48869 non-null  object
#  1   rating      40915 non-null  object
#  2   fresh       54432 non-null  object
#  3   critic      51710 non-null  object
#  4   top_critic  54432 non-null  int64
#  5   publisher   54123 non-null  object
#  6   date        54432 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 3.3+ MB

# %%
tmdb_movies_df = pd.read_csv('Data/tmdb_movies.csv', index_col=0)
tmdb_movies_df.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
tn_movie_budgets_df = pd.read_csv('Data/tn_movie_budgets.csv', index_col=0)
tn_movie_budgets_df.head()
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget domestic_gross worldwide_gross
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279
# 2       $410,600,000   $241,063,875  $1,045,663,875
# 3       $350,000,000    $42,762,350    $149,762,350
# 4       $330,600,000   $459,005,868  $1,403,013,963
# 5       $317,000,000   $620,181,382  $1,316,721,747

# %% [markdown]
# # 2.3 Exploring the datasets

# %% [markdown]
# # DATA UNDERSTANDING
# First, we look into the different tables in the imdb database.
# * Directors table

# %%
# one movie can have multiple directors
# query the db for directors table
q = """
SELECT *
FROM directors
;
"""
directors = pd.read_sql(q, conn)
directors.tail(3)
# Out:
#          movie_id   person_id
# 291171  tt9001494  nm10123242
# 291172  tt9001494  nm10123248
# 291173  tt9004986   nm4993825

# %%
# query the db for known_for table
q = """
SELECT *
FROM movie_akas
;
"""
movie_akas = pd.read_sql(q, conn)
movie_akas.isna().sum(0)
# Out:
# movie_id                  0
# ordering                  0
# title                     0
# region                53293
# language             289988
# types                163256
# attributes           316778
# is_original_title        25
# dtype: int64

# %% [markdown]
# Findings about the directors table:
# 1. movie_id is the primary key
# 2. one movie_id can have multiple person_id i.e multiple directors

# %% [markdown]
# * Persons table

# %%
# query the db for persons table
q = """
SELECT *
FROM persons
;
"""
persons = pd.read_sql(q, conn)
persons.tail()
# Out:
#         person_id         primary_name  birth_year  death_year  \
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#            primary_profession
# 606643                actress
# 606644                actress
# 606645                actress
# 606646               producer
# 606647  director,actor,writer

# %%
persons.nunique()
# Out:
# person_id             606648
# primary_name          577203
# birth_year               267
# death_year               214
# primary_profession      8647
# dtype: int64

# %%
persons[persons['primary_name'].duplicated()].sort_values(by = 'primary_name')
# Out:
#         person_id        primary_name  birth_year  death_year  \
# 279631  nm4062141        A. Venkatesh         NaN         NaN
# 156216  nm1701176        A. Venkatesh         NaN         NaN
# 387377  nm8956236        A. Venkatesh         NaN         NaN
# 436444  nm6758318           A.J. Khan         NaN         NaN
# 565680  nm7645047           A.K. Azad         NaN         NaN
# ...           ...                 ...         ...         ...
# 290560  nm3216359         Óscar Pérez         NaN         NaN
# 446899  nm7114545       Özer Kiziltan         NaN         NaN
# 433984  nm6356309         Özgür Bakar         NaN         NaN
# 603769  nm8122779       Øystein Mamen         NaN         NaN
# 173454  nm1800527  Þórunn Lárusdóttir         NaN         NaN
#
#                               primary_profession
# 279631                     director,actor,writer
# 156216  cinematographer,camera_department,editor
# 387377                                  producer
# 436444                                  producer
# 565680                 music_department,composer
# ...                                          ...
# 290560                  producer,director,writer
# 446899                           cinematographer
# 433984                  director,writer,producer
# 603769                           cinematographer
# 173454                          actress,director
#
# [29445 rows x 5 columns]

# %%
persons['primary_profession'].str.contains('director').sum()
# Out:
# 146033

# %%
# query the db for principals table
q = """
SELECT *
FROM principals
;
"""
principals = pd.read_sql(q, conn)
principals.head(3)
# Out:
#     movie_id  ordering  person_id  category       job   characters
# 0  tt0111414         1  nm0246005     actor      None  ["The Man"]
# 1  tt0111414         2  nm0398271  director      None         None
# 2  tt0111414         3  nm3739909  producer  producer         None

# %% [markdown]
# Findings about the persons table:
# 1. person_id is the primary key of the persons table
# 2. person_id is the foreign key of the directors, principals table.
# 3. the same name has been used on multiple person_id and profession, suggesting that one person may have played different roles in different movies. THough we are only interested in the director profession which appears 146033 times
#
# APPROACH:
# the directors table and persons table can be useful in determining the highest rated directors using the person_id

# %% [markdown]
# * Movie_basics table

# %%
q = """
SELECT *
FROM movie_basics
;
"""
movie_basics = pd.read_sql(q, conn)
movie_basics.head(10)
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
# 5  tt0111414                      A Thin Life                 A Thin Life
# 6  tt0112502                          Bigfoot                     Bigfoot
# 7  tt0137204                  Joe Finds Grace             Joe Finds Grace
# 8  tt0139613                       O Silêncio                  O Silêncio
# 9  tt0144449            Nema aviona za Zagreb       Nema aviona za Zagreb
#
#    start_year  runtime_minutes                      genres
# 0        2013            175.0          Action,Crime,Drama
# 1        2019            114.0             Biography,Drama
# 2        2018            122.0                       Drama
# 3        2018              NaN                Comedy,Drama
# 4        2017             80.0        Comedy,Drama,Fantasy
# 5        2018             75.0                      Comedy
# 6        2017              NaN             Horror,Thriller
# 7        2017             83.0  Adventure,Animation,Comedy
# 8        2012              NaN         Documentary,History
# 9        2012             82.0                   Biography

# %%
# fins all the years in the table
# see if they are valid formats
movie_basics.start_year.unique()
# Out:
# array([2013, 2019, 2018, 2017, 2012, 2010, 2011, 2015, 2021, 2016, 2014,
#        2020, 2022, 2023, 2024, 2026, 2025, 2115, 2027], dtype=int64)

# %%
"""
 We can see that there are more entries in the movie_id column than the primary_title column.
 Suggesting that there may be some movies repeated 
"""
# Out:
# '\n We can see that there are more entries in the movie_id column than the primary_title column.\n Suggesting that there may be some movies repeated \n'

# %%
movie_basics[movie_basics['primary_title'].duplicated()].tail(10)
# Out:
#          movie_id  primary_title original_title  start_year  runtime_minutes  \
# 146053  tt9903716         Jessie         Jessie        2019            106.0
# 146068  tt9905256      The Cross      The Cross        2012              NaN
# 146078  tt9906218    Unstoppable    Unstoppable        2019             84.0
# 146106  tt9910778        DK Bose        DK Bose        2019            117.0
# 146117  tt9913418      Fragments      Fragments        2019              NaN
# 146119  tt9913594    Bacchanalia    Bacchanalia        2017             72.0
# 146120  tt9913936       Paradise       Paradise        2019              NaN
# 146125  tt9914642      Albatross      Albatross        2017              NaN
# 146134  tt9916160     Drømmeland     Drømmeland        2019             72.0
# 146135  tt9916170  The Rehearsal       O Ensaio        2019             51.0
#
#                         genres
# 146053         Horror,Thriller
# 146068                Thriller
# 146078             Documentary
# 146106                  Comedy
# 146117    Drama,Mystery,Sci-Fi
# 146119  Drama,Mystery,Thriller
# 146120             Crime,Drama
# 146125             Documentary
# 146134             Documentary
# 146135                   Drama

# %%
movie_basics[movie_basics['primary_title'] == 'Albatross']
# Out:
#          movie_id primary_title original_title  start_year  runtime_minutes  \
# 9094    tt1541149     Albatross      Albatross        2011             90.0
# 53042   tt3128706     Albatross      Albatross        2015             89.0
# 146125  tt9914642     Albatross      Albatross        2017              NaN
#
#                     genres
# 9094                 Drama
# 53042   Comedy,Drama,Sport
# 146125         Documentary

# %%
movie_basics[movie_basics['primary_title'] == 'The Rehearsal']
# Out:
#          movie_id  primary_title original_title  start_year  runtime_minutes  \
# 99621   tt5820812  The Rehearsal  The Rehearsal        2016            102.0
# 146135  tt9916170  The Rehearsal       O Ensaio        2019             51.0
#
#        genres
# 99621   Drama
# 146135  Drama

# %%
movie_basics[movie_basics['primary_title'] == 'Bacchanalia']
# Out:
#          movie_id primary_title original_title  start_year  runtime_minutes  \
# 53806   tt3167458   Bacchanalia    Bacchanalia        2017            101.0
# 146119  tt9913594   Bacchanalia    Bacchanalia        2017             72.0
#
#                         genres
# 53806            Comedy,Horror
# 146119  Drama,Mystery,Thriller

# %% [markdown]
# Findings about the movie_basics table:
# 1. Primary key: movie_id
# 2. Foreign Key: movie_id linking to the directors table.
# 3. It is confirmed that there are duplicate entries in the primary_title column with different movie_ids, start_year, runtime_minutes and genres.
# 4. One major problem with the duplicate primary_titles is that the start_year are different on different rows and would be hard to determine which start_year should be used in analyses.
# 5. the start year also seems to have entries in future dates. Such data can be regarded as false and is necessary to be dropped
# 6. Some movies have multiple genres. Can be important to consider when determining the most profitable genre. We can split the text.

# %% [markdown]
# *  Movie_ratings table

# %%
# query the db for movie_ratings table
q = """
SELECT *
FROM movie_ratings
;
"""
movie_ratings = pd.read_sql(q, conn)
movie_ratings.head(3)
# Out:
#      movie_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20

# %%
# search for duplicate rows. 
print(movie_ratings.duplicated().sum())
# Out:
# 0

# %%
movie_basics[movie_basics['movie_id'] == 'tt9894098']
# Out:
#          movie_id primary_title original_title  start_year  runtime_minutes  \
# 145992  tt9894098        Sathru         Sathru        2019            129.0
#
#           genres
# 145992  Thriller

# %%
directors[directors['movie_id'] == 'tt9894098']
# Out:
#          movie_id   person_id
# 141058  tt9894098  nm10529107

# %%
# here we confirm the relationship between the movie_basic,directors, persons, movies_basics tables
persons[persons['person_id'] == 'nm10529107']
# Out:
#         person_id      primary_name  birth_year  death_year primary_profession
# 50054  nm10529107  Naveen Nanjundan         NaN         NaN           director

# %% [markdown]
# Findings about the movie_ratings table:
# 1. Primary Key: movie_id
# 2. Foreign Key: movie_id linking to the directors, principals and movie_basics tables
# 3. average rating may be used to estimate popularity of each film.

# %% [markdown]
# # 4.DATA PREPARATION
# This section describes various steps to clean the data to answer specific questions and as such will highlight the question to be investigated, datasets used and ends with a summary of inferences made for each question
#
# ## 4.1.CLEANING THE IMDB database

# %%
# first we will merge the differnt tables

movie_table_q = """
SELECT 
    movie_id,
    primary_title AS title,
    start_year AS release_year,
    runtime_minutes ,
    genres,
    averagerating AS avg_rating,
    numvotes

FROM movie_basics
JOIN movie_ratings
    USING(movie_id)
;
"""
moviesTable = pd.read_sql(movie_table_q, conn)
moviesTable.head(10)
# Out:
#     movie_id                               title  release_year  \
# 0  tt0063540                           Sunghursh          2013
# 1  tt0066787     One Day Before the Rainy Season          2019
# 2  tt0069049          The Other Side of the Wind          2018
# 3  tt0069204                     Sabse Bada Sukh          2018
# 4  tt0100275            The Wandering Soap Opera          2017
# 5  tt0112502                             Bigfoot          2017
# 6  tt0137204                     Joe Finds Grace          2017
# 7  tt0146592                         Pál Adrienn          2010
# 8  tt0154039                So Much for Justice!          2010
# 9  tt0159369  Cooper and Hemingway: The True Gen          2013
#
#    runtime_minutes                      genres  avg_rating  numvotes
# 0            175.0          Action,Crime,Drama         7.0        77
# 1            114.0             Biography,Drama         7.2        43
# 2            122.0                       Drama         6.9      4517
# 3              NaN                Comedy,Drama         6.1        13
# 4             80.0        Comedy,Drama,Fantasy         6.5       119
# 5              NaN             Horror,Thriller         4.1        32
# 6             83.0  Adventure,Animation,Comedy         8.1       263
# 7            136.0                       Drama         6.8       451
# 8            100.0                     History         4.6        64
# 9            180.0                 Documentary         7.6        53

# %%
# join the tables principals,  to get specific directors 
directors_table_query = """
SELECT 
    movie_id,
    primary_name AS director
FROM principals
JOIN persons
    USING(person_id)
WHERE category = 'director'

;
"""
directorsTable = pd.read_sql(directors_table_query,conn)
directorsTable.head(3)
# Out:
#     movie_id           director
# 0  tt0111414       Frank Howson
# 1  tt0323808        Robin Hardy
# 2  tt0417610  Alejandro Chomski

# %%
directorsTable = directorsTable.drop_duplicates()

# %%
directorsTable = directorsTable.groupby('movie_id')['director'].apply(list)
directorsTable.head()
# Out:
# movie_id
# tt0063540              [Harnam Singh Rawail]
# tt0066787                        [Mani Kaul]
# tt0069049                     [Orson Welles]
# tt0069204             [Hrishikesh Mukherjee]
# tt0100275    [Raoul Ruiz, Valeria Sarmiento]
# Name: director, dtype: object

# %%
"""
One movie can have multiple directors and would be useful to put all directors of a movie
 based on movie_id as a list

"""
# Out:
# '\nOne movie can have multiple directors and would be useful to put all directors of a movie\n based on movie_id as a list\n\n'

# %%
actors_table_query = """
SELECT 
    movie_id,
    primary_name AS actor
FROM principals
JOIN persons
    USING(person_id)
WHERE category = 'actor'
;
"""
actorsTable = pd.read_sql(actors_table_query, conn)

actorsTable = actorsTable.drop_duplicates()

actorsTable = actorsTable.groupby('movie_id')['actor'].apply(list)
actorsTable.head()
# Out:
# movie_id
# tt0063540       [Dilip Kumar, Balraj Sahni, Sanjeev Kumar]
# tt0066787                      [Arun Khopkar, Om Shivpuri]
# tt0069049                 [John Huston, Peter Bogdanovich]
# tt0069204    [Rabi Ghosh, Vijay Arora, Asrani, Utpal Dutt]
# tt0100275                  [Luis Alarcón, Francisco Reyes]
# Name: actor, dtype: object

# %%
imdb_table1 = pd.merge(moviesTable, directorsTable, how='left', on='movie_id')

imdb_Table = pd.merge(imdb_table1, actorsTable, how='left', on='movie_id')

imdb_Table.isna().sum()
# Out:
# movie_id               0
# title                  0
# release_year           0
# runtime_minutes     7620
# genres               804
# avg_rating             0
# numvotes               0
# director            6099
# actor              15856
# dtype: int64

# %%
imdb_Table[imdb_Table['title'].str.contains('-|:|;')].sample(5)
# Out:
#         movie_id                                              title  \
# 28507  tt2751468                        Lakey Peterson: Zero to 100
# 68783  tt7865612                   Aghora: The Deadliest Blackmagic
# 41036  tt3894528                                              11:11
# 1716   tt1277373                        Umizaru 3: The Last Message
# 52728  tt5268086  Forgotten Scares: An In-depth Look at Flemish ...
#
#        release_year  runtime_minutes              genres  avg_rating  \
# 28507          2013             60.0   Documentary,Sport         6.2
# 68783          2018              NaN              Horror         7.9
# 41036          2015             60.0  Drama,Music,Sci-Fi         6.3
# 1716           2010              NaN               Drama         6.2
# 52728          2016             96.0  Documentary,Horror         7.0
#
#        numvotes               director  \
# 28507       139         [Aaron Lieber]
# 68783         7      [Francois Larosa]
# 41036         6  [R. Stephenson Price]
# 1716        156      [Eiichirô Hasumi]
# 52728       109      [Steve De Roover]
#
#                                                    actor
# 28507                                                NaN
# 68783                          [Tj Condit, Scott Fulmer]
# 41036                  [Douglas Arthur Carlsen, Zac Che]
# 1716   [Hideaki Itô, Soji Arai, Ryûta Satô, Masaya Katô]
# 52728                                                NaN

# %%
# fill NaN runtime rows with the median 
imdb_Table['runtime_minutes'].fillna(imdb_Table['runtime_minutes'].median(), inplace = True)
imdb_Table.head()
# Out:
#     movie_id                            title  release_year  runtime_minutes  \
# 0  tt0063540                        Sunghursh          2013            175.0
# 1  tt0066787  One Day Before the Rainy Season          2019            114.0
# 2  tt0069049       The Other Side of the Wind          2018            122.0
# 3  tt0069204                  Sabse Bada Sukh          2018             91.0
# 4  tt0100275         The Wandering Soap Opera          2017             80.0
#
#                  genres  avg_rating  numvotes  \
# 0    Action,Crime,Drama         7.0        77
# 1       Biography,Drama         7.2        43
# 2                 Drama         6.9      4517
# 3          Comedy,Drama         6.1        13
# 4  Comedy,Drama,Fantasy         6.5       119
#
#                           director  \
# 0            [Harnam Singh Rawail]
# 1                      [Mani Kaul]
# 2                   [Orson Welles]
# 3           [Hrishikesh Mukherjee]
# 4  [Raoul Ruiz, Valeria Sarmiento]
#
#                                            actor
# 0     [Dilip Kumar, Balraj Sahni, Sanjeev Kumar]
# 1                    [Arun Khopkar, Om Shivpuri]
# 2               [John Huston, Peter Bogdanovich]
# 3  [Rabi Ghosh, Vijay Arora, Asrani, Utpal Dutt]
# 4                [Luis Alarcón, Francisco Reyes]

# %%
# drop rows whose start year are future dates > 2024
imdb_Table.drop(imdb_Table[imdb_Table.release_year > 2024].index, inplace = True)

# %%
imdb_Table.release_year.unique()
# Out:
# array([2013, 2019, 2018, 2017, 2010, 2011, 2012, 2015, 2016, 2014],
#       dtype=int64)

# %%
imdb_Table[imdb_Table['title'].duplicated()].tail(3)
# Out:
#         movie_id        title  release_year  runtime_minutes       genres  \
# 73845  tt9906218  Unstoppable          2019             84.0  Documentary
# 73853  tt9914642    Albatross          2017             91.0  Documentary
# 73855  tt9916160   Drømmeland          2019             72.0  Documentary
#
#        avg_rating  numvotes              director actor
# 73845         8.1         8        [Nick Willing]   NaN
# 73853         8.5         8        [Chris Jordan]   NaN
# 73855         6.5        11  [Joost van der Wiel]   NaN

# %% [markdown]
# # 4.2.CLEANING THE tn_movie_budgets
# It would be useful to see what movies made high profits.

# %%
tn_movie_budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5782 entries, 1 to 82
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       5782 non-null   object
#  1   movie              5782 non-null   object
#  2   production_budget  5782 non-null   object
#  3   domestic_gross     5782 non-null   object
#  4   worldwide_gross    5782 non-null   object
# dtypes: object(5)
# memory usage: 271.0+ KB

# %%
tn_movie_budgets_df['movie'].duplicated().sum()
# Out:
# 84

# %%
tn_movie_budgets_df[tn_movie_budgets_df['movie'].duplicated()]
# Out:
#      release_date                       movie production_budget  \
# id
# 74   May 19, 1998                    Godzilla      $125,000,000
# 9    Nov 21, 2018                  Robin Hood       $99,000,000
# 85    Jul 8, 2005              Fantastic Four       $87,500,000
# 44    May 7, 1999                   The Mummy       $80,000,000
# 8    Jun 13, 1997                    Hercules       $70,000,000
# ..            ...                         ...               ...
# 69   Nov 16, 1942                  Cat People          $134,000
# 77    Oct 1, 1968    Night of the Living Dead          $114,000
# 78    Feb 8, 1915       The Birth of a Nation          $110,000
# 100  Aug 30, 1972  The Last House on the Left           $87,000
# 19   Feb 22, 2008                  The Signal           $50,000
#
#     domestic_gross worldwide_gross
# id
# 74    $136,314,294    $376,000,000
# 9      $30,824,628     $84,747,441
# 85    $154,696,080    $333,132,750
# 44    $155,385,488    $416,385,488
# 8      $99,112,101    $250,700,000
# ..             ...             ...
# 69      $4,000,000      $8,000,000
# 77     $12,087,064     $30,087,064
# 78     $10,000,000     $11,000,000
# 100     $3,100,000      $3,100,000
# 19        $251,150        $406,299
#
# [84 rows x 5 columns]

# %%
""" 
Next we need to account for duplicates. we find that Godzilla has two differnt years. 
i wouuld deal with these values by concatenating the year to the title..to be able to
 differentiate the two title.
"""
# Out:
# ' \nNext we need to account for duplicates. we find that Godzilla has two differnt years. \ni wouuld deal with these values by concatenating the year to the title..to be able to\n differentiate the two title.\n'

# %%
tn_movie_budgets_df[tn_movie_budgets_df['movie'].str.contains('Part')].head(3)
# Out:
#     release_date                                     movie production_budget  \
# id
# 39  Nov 20, 2015     The Hunger Games: Mockingjay - Part 2      $160,000,000
# 25  Nov 16, 2012  The Twilight Saga: Breaking Dawn, Part 2      $136,200,000
# 57  Nov 18, 2011  The Twilight Saga: Breaking Dawn, Part 1      $127,500,000
#
#    domestic_gross worldwide_gross
# id
# 39   $281,723,902    $648,986,787
# 25   $292,324,737    $829,724,737
# 57   $281,287,133    $689,420,051

# %%
imdb_Table[imdb_Table['title'].str.contains('Part')].head(3)
# Out:
#       movie_id                   title  release_year  runtime_minutes  \
# 116  tt0452664          Party Crashers          2012             88.0
# 147  tt0469021          Alan Partridge          2013             90.0
# 171  tt0480239  Atlas Shrugged: Part I          2011             97.0
#
#                    genres  avg_rating  numvotes               director  \
# 116                Comedy         5.4       907  [Andrucha Waddington]
# 147   Action,Comedy,Crime         6.9     27986        [Declan Lowney]
# 171  Drama,Mystery,Sci-Fi         5.7     12524       [Paul Johansson]
#
#                                                  actor
# 116  [Marcelo Adnet, Eduardo Sterblitch, Stepan Ner...
# 147  [Steve Coogan, Colm Meaney, Tim Key, Karl Theo...
# 171       [Grant Bowler, Matthew Marsden, Edi Gathegi]

# %%
tn_movie_budgets_df[tn_movie_budgets_df['movie'].str.contains('Ep')].head(3)
# Out:
#     release_date                                 movie production_budget  \
# id
# 5   Dec 15, 2017     Star Wars Ep. VIII: The Last Jedi      $317,000,000
# 6   Dec 18, 2015  Star Wars Ep. VII: The Force Awakens      $306,000,000
# 4   May 19, 1999   Star Wars Ep. I: The Phantom Menace      $115,000,000
#
#    domestic_gross worldwide_gross
# id
# 5    $620,181,382  $1,316,721,747
# 6    $936,662,225  $2,053,311,220
# 4    $474,544,677  $1,027,044,677

# %%
imdb_Table[imdb_Table['title'].str.contains('Star Wars')].head(3)
# Out:
#         movie_id                                       title  release_year  \
# 21144  tt2275656               Star Wars: Threads of Destiny          2014
# 25595  tt2488496  Star Wars: Episode VII - The Force Awakens          2015
# 26070  tt2527336                    Star Wars: The Last Jedi          2017
#
#        runtime_minutes                    genres  avg_rating  numvotes  \
# 21144            110.0   Action,Adventure,Sci-Fi         4.1       486
# 25595            136.0  Action,Adventure,Fantasy         8.0    784780
# 26070            152.0  Action,Adventure,Fantasy         7.1    462903
#
#                 director                                         actor
# 21144  [Rasmus Tirzitis]                 [Patrik Hont, Karl Lindqvist]
# 25595      [J.J. Abrams]  [John Boyega, Oscar Isaac, Domhnall Gleeson]
# 26070     [Rian Johnson]                    [John Boyega, Mark Hamill]

# %%
"""
We note that the in both dataframes the naming conventions are no consistent and thus we need to do more cleaning so as to use all the data.
We see that:
1. Sometimes the title name are recorded using Roman numerals and other use Arabic numerals
2. Punctuations are also not consistent
3. The use of 'Ep' instead of 'Episode' 

"""
# Out:
# "\nWe note that the in both dataframes the naming conventions are no consistent and thus we need to do more cleaning so as to use all the data.\nWe see that:\n1. Sometimes the title name are recorded using Roman numerals and other use Arabic numerals\n2. Punctuations are also not consistent\n3. The use of 'Ep' instead of 'Episode' \n\n"

# %%
# remove the punctuation and replace
tn_movie_budgets_df['movie'] = tn_movie_budgets_df['movie'].str.replace(r'[^\w\s]+', '')
imdb_Table['title'] = imdb_Table['title'].str.replace(r'[^\w\s]+', '')

# %%
imdb_Table.dtypes
# Out:
# movie_id            object
# title               object
# release_year         int64
# runtime_minutes    float64
# genres              object
# avg_rating         float64
# numvotes             int64
# director            object
# actor               object
# dtype: object

# %%
# Roman to Integer in Python
# The other way around would replace letter I with 1:
# REF: https://stackoverflow.com/questions/6116978/how-to-replace-multiple-substrings-of-a-string

def romanToInt(title_name, roman_nums_dict):
    for i, j in roman_nums_dict.items():
        title_name = title_name.str.replace(i, j)
    return title_name

roman_nums_dict = {'I': '1', 'II': '2', 'III': '3', 'IV': '4','V': '5', 'VI': '6', 'VII': '7','VIII': '8','IX': '9','X': '10'}
title_name = imdb_Table['title']
imdb_Table['title'] = romanToInt(title_name, roman_nums_dict)

movie_name = tn_movie_budgets_df['movie']
tn_movie_budgets_df['movie'] = romanToInt(movie_name, roman_nums_dict)

imdb_Table.iloc[25595]

# tn_movie_budgets_df.head(10)
# Out:
# movie_id                                              tt2488496
# title                  Star Wars Episode 511  The Force Awakens
# release_year                                               2015
# runtime_minutes                                             136
# genres                                 Action,Adventure,Fantasy
# avg_rating                                                    8
# numvotes                                                 784780
# director                                          [J.J. Abrams]
# actor              [John Boyega, Oscar Isaac, Domhnall Gleeson]
# Name: 25595, dtype: object

# %%
# replace Ep with Episode
tn_movie_budgets_df['movie'] = tn_movie_budgets_df['movie'].str.replace('Ep.','Episode', regex=False)
imdb_Table['title'] = imdb_Table['title'].str.replace('Ep.','Episode', regex=False) # regex=False: Match and extract exact string pattern from the text

# %%
imdb_Table.tail()
# Out:
#         movie_id                       title  release_year  runtime_minutes  \
# 73851  tt9913084            Diabolik sono io          2019             75.0
# 73852  tt9914286           Sokagin Çocuklari          2019             98.0
# 73853  tt9914642                   Albatross          2017             91.0
# 73854  tt9914942  La vida sense la Sara Amat          2019             91.0
# 73855  tt9916160                  Drømmeland          2019             72.0
#
#              genres  avg_rating  numvotes              director  \
# 73851   Documentary         6.2         6     [Giancarlo Soldi]
# 73852  Drama,Family         8.7       136                   NaN
# 73853   Documentary         8.5         8        [Chris Jordan]
# 73854          None         6.6         5           [Laura Jou]
# 73855   Documentary         6.5        11  [Joost van der Wiel]
#
#                                                    actor
# 73851                     [Luciano Scarpa, Riccardo Mei]
# 73852  [Ahmet Faik Akinci, Metin Keçeci, Burhan Sirma...
# 73853                                                NaN
# 73854         [Isaac Alcayde, Joan Amargós, Pau Escobar]
# 73855                                                NaN

# %%
""" 
Next we need to account for duplicates. we find that Godzilla has two differnt years. 
i wouuld deal with these values by concatenating the year to the title..to be able to differentiate the two title.

"""
# Out:
# ' \nNext we need to account for duplicates. we find that Godzilla has two differnt years. \ni wouuld deal with these values by concatenating the year to the title..to be able to differentiate the two title.\n\n'

# %%
tn_movie_budgets_df[tn_movie_budgets_df['movie'] == 'Godzilla']
# Out:
#     release_date     movie production_budget domestic_gross worldwide_gross
# id
# 41  May 16, 2014  Godzilla      $160,000,000   $200,676,069    $529,076,069
# 74  May 19, 1998  Godzilla      $125,000,000   $136,314,294    $376,000,000

# %%
# Before adding the year to the name for these specific movies, let's convert release year into string
# The function below does not work with str() unless you save the variable as string type first. 
# concatenate the two columns

imdb_Table['title'] = imdb_Table['title'].astype(str) + " " + imdb_Table['release_year'].astype(str)

imdb_Table.head()
# Out:
#     movie_id                                 title  release_year  \
# 0  tt0063540                        Sunghursh 2013          2013
# 1  tt0066787  One Day Before the Rainy Season 2019          2019
# 2  tt0069049       The Other Side of the Wind 2018          2018
# 3  tt0069204                  Sabse Bada Sukh 2018          2018
# 4  tt0100275         The Wandering Soap Opera 2017          2017
#
#    runtime_minutes                genres  avg_rating  numvotes  \
# 0            175.0    Action,Crime,Drama         7.0        77
# 1            114.0       Biography,Drama         7.2        43
# 2            122.0                 Drama         6.9      4517
# 3             91.0          Comedy,Drama         6.1        13
# 4             80.0  Comedy,Drama,Fantasy         6.5       119
#
#                           director  \
# 0            [Harnam Singh Rawail]
# 1                      [Mani Kaul]
# 2                   [Orson Welles]
# 3           [Hrishikesh Mukherjee]
# 4  [Raoul Ruiz, Valeria Sarmiento]
#
#                                            actor
# 0     [Dilip Kumar, Balraj Sahni, Sanjeev Kumar]
# 1                    [Arun Khopkar, Om Shivpuri]
# 2               [John Huston, Peter Bogdanovich]
# 3  [Rabi Ghosh, Vijay Arora, Asrani, Utpal Dutt]
# 4                [Luis Alarcón, Francisco Reyes]

# %%
""" 
We notice that some movies from really old to be included 
in this analysis as tastes may have changed over the centuries, 
the value of money as well has changed over the years.

"""
# Out:
# ' \nWe notice that some movies from really old to be included \nin this analysis as tastes may have changed over the centuries, \nthe value of money as well has changed over the years.\n\n'

# %%
# doing the same for the tn_movie_budgets table
# first we would need to extract the release year from the release date to have a column of 
# start_year in the tn_movie_budgets_df

# convert the release_date to datetime
tn_movie_budgets_df['release_date'] = pd.to_datetime(tn_movie_budgets_df['release_date'])
tn_movie_budgets_df['release_year'] = tn_movie_budgets_df['release_date'].dt.year

tn_movie_budgets_df['movie'] = tn_movie_budgets_df['movie'].astype(str) + " " + tn_movie_budgets_df['release_year'].astype(str)

# # drop rows of years that are too far back in the past
# tn_movie_budgets_df.drop(tn_movie_budgets_df[tn_movie_budgets_df.release_year < 2000 ].index, inplace = True)

tn_movie_budgets_df.head()
# Out:
#    release_date                                            movie  \
# id
# 1    2009-12-18                                      Avatar 2009
# 2    2011-05-20  Pirates of the Caribbean On Stranger Tides 2011
# 3    2019-06-07                                Dark Phoenix 2019
# 4    2015-05-01                      Avengers Age of Ultron 2015
# 5    2017-12-15             Star Wars Ep 5111 The Last Jedi 2017
#
#    production_budget domestic_gross worldwide_gross  release_year
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279          2009
# 2       $410,600,000   $241,063,875  $1,045,663,875          2011
# 3       $350,000,000    $42,762,350    $149,762,350          2019
# 4       $330,600,000   $459,005,868  $1,403,013,963          2015
# 5       $317,000,000   $620,181,382  $1,316,721,747          2017

# %%
tn_movie_budgets_df.head()
# Out:
#    release_date                                            movie  \
# id
# 1    2009-12-18                                      Avatar 2009
# 2    2011-05-20  Pirates of the Caribbean On Stranger Tides 2011
# 3    2019-06-07                                Dark Phoenix 2019
# 4    2015-05-01                      Avengers Age of Ultron 2015
# 5    2017-12-15             Star Wars Ep 5111 The Last Jedi 2017
#
#    production_budget domestic_gross worldwide_gross  release_year
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279          2009
# 2       $410,600,000   $241,063,875  $1,045,663,875          2011
# 3       $350,000,000    $42,762,350    $149,762,350          2019
# 4       $330,600,000   $459,005,868  $1,403,013,963          2015
# 5       $317,000,000   $620,181,382  $1,316,721,747          2017

# %%
"""
We would like to use the production budget, dometic_gross, worldwide_gross 
but they are given as object data type.
"""
# Out:
# '\nWe would like to use the production budget, dometic_gross, worldwide_gross \nbut they are given as object data type.\n'

# %%
tn_movie_budgets_df['production_budget'] = tn_movie_budgets_df['production_budget'].astype('string')
tn_movie_budgets_df['domestic_gross'] = tn_movie_budgets_df['domestic_gross'].astype('string')
tn_movie_budgets_df['worldwide_gross'] = tn_movie_budgets_df['worldwide_gross'].astype('string')

tn_movie_budgets_df.dtypes
# Out:
# release_date         datetime64[ns]
# movie                        object
# production_budget            string
# domestic_gross               string
# worldwide_gross              string
# release_year                  int64
# dtype: object

# %%
# we remove the $ sign and the commas and conver string to integer
tn_movie_budgets_df['production_budget'] = tn_movie_budgets_df['production_budget'].str.replace(',', '').str.replace('$', '')
tn_movie_budgets_df['domestic_gross'] = tn_movie_budgets_df['domestic_gross'].str.replace(',', '').str.replace('$', '')
tn_movie_budgets_df['worldwide_gross'] = tn_movie_budgets_df['worldwide_gross'].str.replace(',', '').str.replace('$', '')

# finally we would need to convert these columns into integer to be able to use them in plotting
tn_movie_budgets_df['production_budget'] = tn_movie_budgets_df['production_budget'].astype('int64')
tn_movie_budgets_df['domestic_gross'] = tn_movie_budgets_df['domestic_gross'].astype('int64')
tn_movie_budgets_df['worldwide_gross'] = tn_movie_budgets_df['worldwide_gross'].astype('int64')

tn_movie_budgets_df.dtypes
# Out:
# release_date         datetime64[ns]
# movie                        object
# production_budget             int64
# domestic_gross                int64
# worldwide_gross               int64
# release_year                  int64
# dtype: object

# %% [markdown]
# # 4.MERGING THE FINAL DATATSETS

# %%
# now we merge the two dataframes
final_movie_info_table = imdb_Table.merge(tn_movie_budgets_df, left_on='title', right_on='movie', how='inner')
final_movie_info_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1520 entries, 0 to 1519
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie_id           1520 non-null   object
#  1   title              1520 non-null   object
#  2   release_year_x     1520 non-null   int64
#  3   runtime_minutes    1520 non-null   float64
#  4   genres             1518 non-null   object
#  5   avg_rating         1520 non-null   float64
#  6   numvotes           1520 non-null   int64
#  7   director           1463 non-null   object
#  8   actor              1463 non-null   object
#  9   release_date       1520 non-null   datetime64[ns]
#  10  movie              1520 non-null   object
#  11  production_budget  1520 non-null   int64
#  12  domestic_gross     1520 non-null   int64
#  13  worldwide_gross    1520 non-null   int64
#  14  release_year_y     1520 non-null   int64
# dtypes: datetime64[ns](1), float64(2), int64(6), object(6)
# memory usage: 190.0+ KB

# %%
# clean the resultsing dataset
# drop redundant rows
final_movie_info_table.drop(['movie', 'release_year_y'], axis=1, inplace=True)

final_movie_info_table.rename(columns = {'release_year_x':'release_year'}, inplace = True)

final_movie_info_table.head()
# Out:
#     movie_id                                 title  release_year  \
# 0  tt0249516                        Foodfight 2012          2012
# 1  tt0359950  The Secret Life of Walter Mitty 2013          2013
# 2  tt0365907      A Walk Among the Tombstones 2014          2014
# 3  tt0369610                   Jurassic World 2015          2015
# 4  tt0376136                    The Rum Diary 2011          2011
#
#    runtime_minutes                   genres  avg_rating  numvotes  \
# 0             91.0  Action,Animation,Comedy         1.9      8248
# 1            114.0   Adventure,Comedy,Drama         7.3    275300
# 2            114.0       Action,Crime,Drama         6.5    105116
# 3            124.0  Action,Adventure,Sci-Fi         7.0    539338
# 4            119.0             Comedy,Drama         6.2     94787
#
#               director                                              actor  \
# 0  [Lawrence Kasanoff]                                    [Charlie Sheen]
# 1                  NaN                            [Ben Stiller, Jon Daly]
# 2        [Scott Frank]  [Liam Neeson, Dan Stevens, David Harbour, Boyd...
# 3    [Colin Trevorrow]                         [Chris Pratt, Ty Simpkins]
# 4     [Bruce Robinson]  [Johnny Depp, Giovanni Ribisi, Aaron Eckhart, ...
#
#   release_date  production_budget  domestic_gross  worldwide_gross
# 0   2012-12-31           45000000               0            73706
# 1   2013-12-25           91000000        58236838        187861183
# 2   2014-09-19           28000000        26017685         62108587
# 3   2015-06-12          215000000       652270625       1648854864
# 4   2011-10-28           45000000        13109815         21544732

# %%
final_movie_info_table.release_year.unique()
# Out:
# array([2012, 2013, 2014, 2015, 2011, 2010, 2019, 2016, 2017, 2018],
#       dtype=int64)

# %% [markdown]
# # 5.DATA MODELING
# We need to create other dependant variables to assess the profitability.
# Will create other columns allowing to calculate profit

# %%
# create profit and return on investment column
final_movie_info_table['profit'] = final_movie_info_table['worldwide_gross'] - final_movie_info_table['production_budget'] 
final_movie_info_table['return_on_investment'] = ( (final_movie_info_table['worldwide_gross'] - final_movie_info_table['production_budget'])\
                       / final_movie_info_table['production_budget'] )*100

print(final_movie_info_table['profit'].median())
print(final_movie_info_table['return_on_investment'].median())
print(final_movie_info_table['production_budget'].quantile(q=(0,.25,.5, .75, 1)))
# Out:
# 23214408.0
# 112.34689740740741
# 0.00        15000.0
# 0.25      8000000.0
# 0.50     23000000.0
# 0.75     56525000.0
# 1.00    410600000.0
# Name: production_budget, dtype: float64

# %%
final_movie_info_table.head()
# Out:
#     movie_id                                 title  release_year  \
# 0  tt0249516                        Foodfight 2012          2012
# 1  tt0359950  The Secret Life of Walter Mitty 2013          2013
# 2  tt0365907      A Walk Among the Tombstones 2014          2014
# 3  tt0369610                   Jurassic World 2015          2015
# 4  tt0376136                    The Rum Diary 2011          2011
#
#    runtime_minutes                   genres  avg_rating  numvotes  \
# 0             91.0  Action,Animation,Comedy         1.9      8248
# 1            114.0   Adventure,Comedy,Drama         7.3    275300
# 2            114.0       Action,Crime,Drama         6.5    105116
# 3            124.0  Action,Adventure,Sci-Fi         7.0    539338
# 4            119.0             Comedy,Drama         6.2     94787
#
#               director                                              actor  \
# 0  [Lawrence Kasanoff]                                    [Charlie Sheen]
# 1                  NaN                            [Ben Stiller, Jon Daly]
# 2        [Scott Frank]  [Liam Neeson, Dan Stevens, David Harbour, Boyd...
# 3    [Colin Trevorrow]                         [Chris Pratt, Ty Simpkins]
# 4     [Bruce Robinson]  [Johnny Depp, Giovanni Ribisi, Aaron Eckhart, ...
#
#   release_date  production_budget  domestic_gross  worldwide_gross  \
# 0   2012-12-31           45000000               0            73706
# 1   2013-12-25           91000000        58236838        187861183
# 2   2014-09-19           28000000        26017685         62108587
# 3   2015-06-12          215000000       652270625       1648854864
# 4   2011-10-28           45000000        13109815         21544732
#
#        profit  return_on_investment
# 0   -44926294            -99.836209
# 1    96861183            106.440860
# 2    34108587            121.816382
# 3  1433854864            666.909239
# 4   -23455268            -52.122818

# %% [markdown]
# # 6.VISUALIZATION

# %% [markdown]
# # Q1. Is there a correlation between the runtime and the rating?
# Here we would like to determine the if the optimal length range of a movie for it to be more popular.

# %%
# data visualization
fig, ax1 = plt.subplots(figsize=(8, 6))
sns.regplot(data = final_movie_info_table, x ='runtime_minutes', y='avg_rating', ax=ax1);

ax1.set(xlabel='Runtime in minutes', ylabel='Average rating')
plt.show()

fig.savefig("visualizations/correlation_between_runtime_and_average_rating")

# %% [markdown]
# It is evident that there is positive correlation between the length of the movie with the chances of getting a high rating. Movies with runtime of about 80 - 120 minutes are most popular.

# %% [markdown]
# # Q2. Top 5 genres with the highest return on investment
# Some of the genres column have multiple values separated by commas. It would be necessary to put them into separate columns before grouping them into their genre bins.

# %%
genre_movie_info_df = final_movie_info_table.copy()
genre_movie_info_df = genre_movie_info_df.drop(['runtime_minutes', 'numvotes', 'director', 'release_date'], axis=1)


# Dropping the 2 rows where Genre is null. 
genre_movie_info_df = genre_movie_info_df.dropna(subset=['genres']).reset_index(drop=True)

genre_movie_info_df['genres'] = genre_movie_info_df['genres'].str.split(',')
genre_movie_info_df = genre_movie_info_df.explode('genres') # .explode() adds more rows

# groupby
genre_movie_info_df.groupby("genres")['movie_id'].count().sort_values()

# genre_movie_info_df.head()
# Out:
# genres
# Musical         10
# Western         11
# War             17
# Sport           34
# Documentary     38
# History         39
# Music           48
# Family          97
# Animation      103
# Fantasy        125
# Mystery        129
# Biography      133
# Sci-Fi         135
# Horror         185
# Romance        192
# Crime          236
# Thriller       265
# Adventure      354
# Action         453
# Comedy         524
# Drama          731
# Name: movie_id, dtype: int64

# %%
# select those genres which produced at least 40 movies to be able to draw reliable conclusions:
genre_movie_info_df = genre_movie_info_df.groupby("genres").filter(lambda x: len(x) > 40) 
genre_movie_info_df.groupby("genres")['movie_id'].count()
# Out:
# genres
# Action       453
# Adventure    354
# Animation    103
# Biography    133
# Comedy       524
# Crime        236
# Drama        731
# Family        97
# Fantasy      125
# Horror       185
# Music         48
# Mystery      129
# Romance      192
# Sci-Fi       135
# Thriller     265
# Name: movie_id, dtype: int64

# %%
# data visualization
fig, ax1 = plt.subplots(figsize=(8, 6))
sns.barplot(data = genre_movie_info_df, x ='return_on_investment', y='genres', ax=ax1);

ax1.set(xlabel='Return on Investments', ylabel='Genres')

fig.savefig("visualizations/return_on_investment_vs_genres.png")

# %% [markdown]
# The graph of return on investment vs which genres suggests that the top 5 genres that have the highest return on investment are:
# 1. Mystery
# 2. Horror
# 3. Thriller
# 4. Music
# 5. Animation
#
# This can be a valid inference as the making of such movies would require a higher budget to go into costumes, CGI/ graphics etc.
# Each of the top 5 probably had a high budget as all these come into play in their making

# %% [markdown]
# # Q3. Top 5 genres with the highest average rating?

# %%
# data visualization
fig, ax1 = plt.subplots(figsize=(8, 6))
sns.barplot(data = genre_movie_info_df, x ='avg_rating', y='genres', ax=ax1);

ax1.set(xlabel='Average rating', ylabel='Genres')

fig.savefig("visualizations/rating_vs_genres.png")

# %% [markdown]
# This graph of genres to avg_rating shows that the top 5 more highly rated genres are:
# 1. Biography
# 2. Animation
# 3. Drama
# 4. Sci-fi
# 5. Romance
# The validity of this inference cannot be determined.

# %% [markdown]
# # 7. CONCLUSION
# We developed three recommendations from our analysis for Microsoft Movie Studios:
# - **produce films that are :** Movies with runtime of about 80 - 120 minutes are most popular.
# - **Release films of genres with the highest return on investment:** The genres: Mystery, Horror, Thriller, Music, Animation.
# - **Release films of genres with the highest average rating:** Since movies with a budget over 150 million dollars displayed a greater return-on-investment, Microsoft Movie Studios should invest within the recommended budget range.
